# %%
gff_files_and_source_urls = {"S_aureus.gff.gz" : "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/013/425/GCF_000013425.1_ASM1342v1/GCF_000013425.1_ASM1342v1_genomic.gff.gz",
                           "S_typhimurium.gff.gz" : "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/195/995/GCF_000195995.1_ASM19599v1/GCF_000195995.1_ASM19599v1_genomic.gff.gz",
                           "E_coli.gff.gz":"ftp://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Escherichia_coli/reference/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gff.gz"}

# %%
for gff_file, source_url in gff_files_and_source_urls.items():
    print(gff_file)
    print(source_url)
# Out:
# S_aureus.gff.gz
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/013/425/GCF_000013425.1_ASM1342v1/GCF_000013425.1_ASM1342v1_genomic.gff.gz
# S_typhimurium.gff.gz
# ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/195/995/GCF_000195995.1_ASM19599v1/GCF_000195995.1_ASM19599v1_genomic.gff.gz
# E_coli.gff.gz
# ftp://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Escherichia_coli/reference/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gff.gz

# %%
import urllib.request
import pandas as pd

# %%
urllib.request.urlretrieve(
# Out:
# ('E_coli.gff.gz', <email.message.Message at 0x1a331bdd1c0>)

# %%
gff_data = pd.read_csv(gff_file, sep="\t", comment='#')

# %%
gff_data
# Out:
#        NC_000913.3  RefSeq region        1  4641652  .  + ..1  \
# 0      NC_000913.3  RefSeq   gene      190      255  .  +   .
# 1      NC_000913.3  RefSeq    CDS      190      255  .  +   0
# 2      NC_000913.3  RefSeq   gene      337     2799  .  +   .
# 3      NC_000913.3  RefSeq    CDS      337     2799  .  +   0
# 4      NC_000913.3  RefSeq   gene     2801     3733  .  +   .
# ...            ...     ...    ...      ...      ... .. ..  ..
# 10115  NC_000913.3  RefSeq    CDS  4639590  4640306  .  -   0
# 10116  NC_000913.3  RefSeq   gene  4640402  4640542  .  +   .
# 10117  NC_000913.3  RefSeq    CDS  4640402  4640542  .  +   0
# 10118  NC_000913.3  RefSeq   gene  4640942  4641628  .  +   .
# 10119  NC_000913.3  RefSeq    CDS  4640942  4641628  .  +   0
#
#       ID=NC_000913.3:1..4641652;Dbxref=taxon:511145;Is_circular=true;Name=ANONYMOUS;gbkey=Src;genome=chromosome;mol_type=genomic DNA;strain=K-12;substrain=MG1655
# 0      ID=gene-b0001;Dbxref=ASAP:ABE-0000006,ECOCYC:E...
# 1      ID=cds-NP_414542.1;Parent=gene-b0001;Dbxref=Un...
# 2      ID=gene-b0002;Dbxref=ASAP:ABE-0000008,ECOCYC:E...
# 3      ID=cds-NP_414543.1;Parent=gene-b0002;Dbxref=Un...
# 4      ID=gene-b0003;Dbxref=ASAP:ABE-0000010,ECOCYC:E...
# ...                                                  ...
# 10115  ID=cds-NP_418818.1;Parent=gene-b4401;Dbxref=Un...
# 10116  ID=gene-b4402;Dbxref=ASAP:ABE-0014437,ECOCYC:G...
# 10117  ID=cds-NP_418819.1;Parent=gene-b4402;Dbxref=Un...
# 10118  ID=gene-b4403;Dbxref=ASAP:ABE-0014442,ECOCYC:E...
# 10119  ID=cds-NP_418820.1;Parent=gene-b4403;Dbxref=Un...
#
# [10120 rows x 9 columns]
